# %% [markdown]
# # Setup, imports

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/honours
# %ls
# Out:
# /content/drive/.shortcut-targets-by-id/19ffbnjWUM9FX-8Hcysq3IAN9wHHnO781/honours
# all/    feature_extraction.py     model_creation.py  plot_functions.py  __pycache__/  sheets/
# dried/  hyperparameter_tuning.py  nonsaturated/      prep_functions.py  saturated/

# %%
from prep_functions import create_images_list, extract_gh_values,extract_lp_values, circle_cut_out, scale_fit_transform
from plot_functions import plot_metrics,lin_regression,plot_predictions,plot_all_validation
from model_creation import build_densenet, build_inception

# %%
import pandas as pd
import cv2
import numpy as np


from google.colab.patches import cv2_imshow #colab bug with imshow

from sklearn.model_selection import KFold

from tensorflow.keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %% [markdown]
# # Data preparation

# %%
#loading two datasets into respective dataframes
gh_df = pd.read_csv('/content/drive/MyDrive/honours/sheets/GrievesHouse.csv')
lp_df = pd.read_csv('/content/drive/MyDrive/honours/sheets/LowerPilmore.csv')

gh_df.head()
# Out:
#   Sample  Stable aggregates (%)
# 0      1                  65.88
# 1      2                  23.90
# 2      2                  31.86
# 3      3                  89.14
# 4      4                  68.71

# %%
# creating lists of images(scaled down) and respective label
gh_path = "/content/drive/MyDrive/honours/all/GrievesHouse/*.*"
lp_path = "/content/drive/MyDrive/honours/all/LowerPilmore/*.*"

gh_colour,gh_labels = create_images_list(gh_path,(256,256))
lp_colour,lp_labels = create_images_list(lp_path,(256,256))

# %%
gh_values = extract_gh_values(gh_labels,gh_df)
lp_values = extract_lp_values(lp_labels,lp_df)

# %% [markdown]
# #Data normalisation

# %%
gh_colour = [circle_cut_out(i) for i in gh_colour]
lp_colour = [circle_cut_out(i) for i in lp_colour]

# gh_colour = [img / 255 for img in gh_colour]
# lp_colour = [img / 255 for img in lp_colour]

X_col = gh_colour + lp_colour
y = gh_values + lp_values

y = np.array(y).reshape(-1, 1)

X_col = np.reshape(X_col,(len(X_col),256,256,3))

# %% [markdown]
# # Inception

# %%
kf = KFold(n_splits=5,shuffle=True,random_state=42)

# %%
all_val_preds = []
all_val_true = []
for i,(train_idx,test_idx) in enumerate(kf.split(X_col)):
  print('-'*66)
  print('-'*30+f'Fold {i}'+'-'*30)
  print('-'*66)

  X_train = np.take(X_col, train_idx, axis=0)
  y_train = np.take(y, train_idx, axis=0)

  X_val = np.take(X_col, test_idx, axis=0)
  y_val = np.take(y, test_idx, axis=0)

  y_train,y_val = scale_fit_transform(y_train,y_val)

  model = build_inception((256,256,3),512,0.3,0.001)
  h = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val,y_val))
  plot_metrics(h,['loss','root_mean_squared_error','mean_absolute_error'],f'D1 WSA: InceptionV3 split{i}')

  y_val_pred = model.predict(X_val)
  y_train_pred = model.predict(X_train)
  all_val_preds.append(y_val_pred)
  all_val_true.append(y_val)

  plot_predictions(y_val.reshape(-1, 1),y_val_pred,y_train.reshape(-1, 1),y_train_pred,f'D1 WSA: Inception split {i}')

plot_all_validation(all_val_true,all_val_preds,'D1 WSA: InceptionV3 total validation')
# Out:
# ------------------------------------------------------------------
# ------------------------------Fold 0------------------------------
# ------------------------------------------------------------------
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step
# Epoch 1/20
# 7/7 [==============================] - 19s 1s/step - loss: 17.0228 - mean_absolute_error: 3.3728 - root_mean_squared_error: 4.1259 - val_loss: 0.8960 - val_mean_absolute_error: 0.7988 - val_root_mean_squared_error: 0.9466
# Epoch 2/20
# 7/7 [==============================] - 1s 102ms/step - loss: 2.6726 - mean_absolute_error: 1.3116 - root_mean_squared_error: 1.6348 - val_loss: 0.8435 - val_mean_absolute_error: 0.7710 - val_root_mean_squared_error: 0.9184
# Epoch 3/20
# 7/7 [==============================] - 1s 109ms/step - loss: 1.5082 - mean_absolute_error: 1.0136 - root_mean_squared_error: 1.2281 - val_loss: 1.3635 - val_mean_absolute_error: 0.9341 - val_root_mean_squared_error: 1.1677
# Epoch 4/20
# 7/7 [==============================] - 1s 106ms/step - loss: 1.2529 - mean_absolute_error: 0.9196 - root_mean_squared_error: 1.1193 - val_loss: 0.7999 - val_mean_absolute_error: 0.7385 - val_root_mean_squared_error: 0.8944
# Epoch 5/20
# 7/7 [==============================] - 1s 108ms/step - loss: 1.1416 - mean_absolute_error: 0.8650 - root_mean_squared_error: 1.0685 - val_loss: 0.8585 - val_mean_absolute_error: 0.7216 - val_root_mean_squared_error: 0.9266
# Epoch 6/20
# 7/7 [==============================] - 1s 108ms/step - loss: 1.1100 - mean_absolute_error: 0.8614 - root_mean_squared_error: 1.0536 - val_loss: 0.7169 - val_mean_absolute_error: 0.6777 - val_root_mean_squared_error: 0.8467
# Epoch 7/20
# 7/7 [==============================] - 1s 100ms/step - loss: 1.0822 - mean_absolute_error: 0.8256 - root_mean_squared_error: 1.0403 - val_loss: 0.7077 - val_mean_absolute_error: 0.6762 - val_root_mean_squared_error: 0.8413
# Epoch 8/20
# 7/7 [==============================] - 1s 101ms/step - loss: 0.9985 - mean_absolute_error: 0.7953 - root_mean_squared_error: 0.9993 - val_loss: 0.7167 - val_mean_absolute_error: 0.6769 - val_root_mean_squared_error: 0.8466
# Epoch 9/20
# 7/7 [==============================] - 1s 101ms/step - loss: 0.9328 - mean_absolute_error: 0.7911 - root_mean_squared_error: 0.9658 - val_loss: 0.7162 - val_mean_absolute_error: 0.6820 - val_root_mean_squared_error: 0.8463
# Epoch 10/20
# 7/7 [==============================] - 1s 104ms/step - loss: 1.0385 - mean_absolute_error: 0.8162 - root_mean_squared_error: 1.0191 - val_loss: 0.7332 - val_mean_absolute_error: 0.6802 - val_root_mean_squared_error: 0.8563
# Epoch 11/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.9631 - mean_absolute_error: 0.7911 - root_mean_squared_error: 0.9814 - val_loss: 0.7021 - val_mean_absolute_error: 0.6824 - val_root_mean_squared_error: 0.8379
# Epoch 12/20
# 7/7 [==============================] - 1s 104ms/step - loss: 0.9701 - mean_absolute_error: 0.7924 - root_mean_squared_error: 0.9850 - val_loss: 0.7077 - val_mean_absolute_error: 0.6739 - val_root_mean_squared_error: 0.8413
# Epoch 13/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9531 - mean_absolute_error: 0.7784 - root_mean_squared_error: 0.9762 - val_loss: 0.7003 - val_mean_absolute_error: 0.6708 - val_root_mean_squared_error: 0.8368
# Epoch 14/20
# 7/7 [==============================] - 1s 110ms/step - loss: 0.9443 - mean_absolute_error: 0.7820 - root_mean_squared_error: 0.9717 - val_loss: 0.7629 - val_mean_absolute_error: 0.6898 - val_root_mean_squared_error: 0.8734
# Epoch 15/20
# 7/7 [==============================] - 1s 109ms/step - loss: 0.9668 - mean_absolute_error: 0.7924 - root_mean_squared_error: 0.9833 - val_loss: 0.7606 - val_mean_absolute_error: 0.7221 - val_root_mean_squared_error: 0.8721
# Epoch 16/20
# 7/7 [==============================] - 1s 109ms/step - loss: 1.0738 - mean_absolute_error: 0.8109 - root_mean_squared_error: 1.0363 - val_loss: 0.7159 - val_mean_absolute_error: 0.6911 - val_root_mean_squared_error: 0.8461
# Epoch 17/20
# 7/7 [==============================] - 1s 102ms/step - loss: 0.9319 - mean_absolute_error: 0.7713 - root_mean_squared_error: 0.9653 - val_loss: 0.7208 - val_mean_absolute_error: 0.6799 - val_root_mean_squared_error: 0.8490
# Epoch 18/20
# 7/7 [==============================] - 1s 100ms/step - loss: 0.9507 - mean_absolute_error: 0.7777 - root_mean_squared_error: 0.9750 - val_loss: 0.7022 - val_mean_absolute_error: 0.6793 - val_root_mean_squared_error: 0.8380
# Epoch 19/20
# 7/7 [==============================] - 1s 100ms/step - loss: 0.9074 - mean_absolute_error: 0.7694 - root_mean_squared_error: 0.9526 - val_loss: 0.7120 - val_mean_absolute_error: 0.6815 - val_root_mean_squared_error: 0.8438
# Epoch 20/20
# 7/7 [==============================] - 1s 100ms/step - loss: 0.9255 - mean_absolute_error: 0.7857 - root_mean_squared_error: 0.9620 - val_loss: 0.7183 - val_mean_absolute_error: 0.6843 - val_root_mean_squared_error: 0.8475
# 2/2 [==============================] - 2s 127ms/step
# 7/7 [==============================] - 0s 74ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 1------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 8s 357ms/step - loss: 8.8685 - mean_absolute_error: 2.3548 - root_mean_squared_error: 2.9780 - val_loss: 1.6057 - val_mean_absolute_error: 1.0502 - val_root_mean_squared_error: 1.2671
# Epoch 2/20
# 7/7 [==============================] - 1s 105ms/step - loss: 2.5578 - mean_absolute_error: 1.3453 - root_mean_squared_error: 1.5993 - val_loss: 2.8670 - val_mean_absolute_error: 1.3668 - val_root_mean_squared_error: 1.6932
# Epoch 3/20
# 7/7 [==============================] - 1s 101ms/step - loss: 1.3695 - mean_absolute_error: 0.9059 - root_mean_squared_error: 1.1702 - val_loss: 1.4750 - val_mean_absolute_error: 0.9826 - val_root_mean_squared_error: 1.2145
# Epoch 4/20
# 7/7 [==============================] - 1s 104ms/step - loss: 1.5186 - mean_absolute_error: 1.0233 - root_mean_squared_error: 1.2323 - val_loss: 1.7895 - val_mean_absolute_error: 1.0703 - val_root_mean_squared_error: 1.3377
# Epoch 5/20
# 7/7 [==============================] - 1s 104ms/step - loss: 1.0260 - mean_absolute_error: 0.7931 - root_mean_squared_error: 1.0129 - val_loss: 1.2971 - val_mean_absolute_error: 0.9251 - val_root_mean_squared_error: 1.1389
# Epoch 6/20
# 7/7 [==============================] - 1s 104ms/step - loss: 1.0347 - mean_absolute_error: 0.8208 - root_mean_squared_error: 1.0172 - val_loss: 1.5157 - val_mean_absolute_error: 1.0163 - val_root_mean_squared_error: 1.2311
# Epoch 7/20
# 7/7 [==============================] - 1s 101ms/step - loss: 0.9570 - mean_absolute_error: 0.7558 - root_mean_squared_error: 0.9782 - val_loss: 1.3838 - val_mean_absolute_error: 0.9648 - val_root_mean_squared_error: 1.1764
# Epoch 8/20
# 7/7 [==============================] - 1s 104ms/step - loss: 0.9736 - mean_absolute_error: 0.7979 - root_mean_squared_error: 0.9867 - val_loss: 1.4704 - val_mean_absolute_error: 0.9940 - val_root_mean_squared_error: 1.2126
# Epoch 9/20
# 7/7 [==============================] - 1s 104ms/step - loss: 0.9779 - mean_absolute_error: 0.7587 - root_mean_squared_error: 0.9889 - val_loss: 1.4466 - val_mean_absolute_error: 0.9781 - val_root_mean_squared_error: 1.2028
# Epoch 10/20
# 7/7 [==============================] - 1s 103ms/step - loss: 0.9979 - mean_absolute_error: 0.7773 - root_mean_squared_error: 0.9989 - val_loss: 1.4584 - val_mean_absolute_error: 0.9771 - val_root_mean_squared_error: 1.2076
# Epoch 11/20
# 7/7 [==============================] - 1s 101ms/step - loss: 0.9283 - mean_absolute_error: 0.7529 - root_mean_squared_error: 0.9635 - val_loss: 1.3674 - val_mean_absolute_error: 0.9461 - val_root_mean_squared_error: 1.1694
# Epoch 12/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.8875 - mean_absolute_error: 0.7440 - root_mean_squared_error: 0.9421 - val_loss: 1.4177 - val_mean_absolute_error: 0.9657 - val_root_mean_squared_error: 1.1907
# Epoch 13/20
# 7/7 [==============================] - 1s 102ms/step - loss: 0.8706 - mean_absolute_error: 0.7329 - root_mean_squared_error: 0.9331 - val_loss: 1.3642 - val_mean_absolute_error: 0.9500 - val_root_mean_squared_error: 1.1680
# Epoch 14/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.9180 - mean_absolute_error: 0.7656 - root_mean_squared_error: 0.9581 - val_loss: 1.3321 - val_mean_absolute_error: 0.9283 - val_root_mean_squared_error: 1.1541
# Epoch 15/20
# 7/7 [==============================] - 1s 112ms/step - loss: 0.8626 - mean_absolute_error: 0.7259 - root_mean_squared_error: 0.9287 - val_loss: 1.3305 - val_mean_absolute_error: 0.9148 - val_root_mean_squared_error: 1.1535
# Epoch 16/20
# 7/7 [==============================] - 1s 111ms/step - loss: 0.9312 - mean_absolute_error: 0.7672 - root_mean_squared_error: 0.9650 - val_loss: 1.3311 - val_mean_absolute_error: 0.9260 - val_root_mean_squared_error: 1.1537
# Epoch 17/20
# 7/7 [==============================] - 1s 112ms/step - loss: 0.8995 - mean_absolute_error: 0.7571 - root_mean_squared_error: 0.9484 - val_loss: 1.3468 - val_mean_absolute_error: 0.9461 - val_root_mean_squared_error: 1.1605
# Epoch 18/20
# 7/7 [==============================] - 1s 103ms/step - loss: 0.8855 - mean_absolute_error: 0.7557 - root_mean_squared_error: 0.9410 - val_loss: 1.5122 - val_mean_absolute_error: 0.9931 - val_root_mean_squared_error: 1.2297
# Epoch 19/20
# 7/7 [==============================] - 1s 106ms/step - loss: 0.9741 - mean_absolute_error: 0.7710 - root_mean_squared_error: 0.9870 - val_loss: 1.4765 - val_mean_absolute_error: 0.9768 - val_root_mean_squared_error: 1.2151
# Epoch 20/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.9139 - mean_absolute_error: 0.7734 - root_mean_squared_error: 0.9560 - val_loss: 1.3707 - val_mean_absolute_error: 0.9519 - val_root_mean_squared_error: 1.1708
# 2/2 [==============================] - 1s 129ms/step
# 7/7 [==============================] - 0s 76ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 2------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 13s 1s/step - loss: 18.6313 - mean_absolute_error: 3.5195 - root_mean_squared_error: 4.3164 - val_loss: 0.9290 - val_mean_absolute_error: 0.7932 - val_root_mean_squared_error: 0.9639
# Epoch 2/20
# 7/7 [==============================] - 1s 104ms/step - loss: 2.9254 - mean_absolute_error: 1.4454 - root_mean_squared_error: 1.7104 - val_loss: 1.1797 - val_mean_absolute_error: 0.8828 - val_root_mean_squared_error: 1.0862
# Epoch 3/20
# 7/7 [==============================] - 1s 104ms/step - loss: 1.8214 - mean_absolute_error: 1.0699 - root_mean_squared_error: 1.3496 - val_loss: 1.1093 - val_mean_absolute_error: 0.8339 - val_root_mean_squared_error: 1.0532
# Epoch 4/20
# 7/7 [==============================] - 1s 107ms/step - loss: 1.1771 - mean_absolute_error: 0.8644 - root_mean_squared_error: 1.0850 - val_loss: 1.1181 - val_mean_absolute_error: 0.8656 - val_root_mean_squared_error: 1.0574
# Epoch 5/20
# 7/7 [==============================] - 1s 110ms/step - loss: 1.0290 - mean_absolute_error: 0.8333 - root_mean_squared_error: 1.0144 - val_loss: 0.8898 - val_mean_absolute_error: 0.7604 - val_root_mean_squared_error: 0.9433
# Epoch 6/20
# 7/7 [==============================] - 1s 110ms/step - loss: 1.0802 - mean_absolute_error: 0.8407 - root_mean_squared_error: 1.0393 - val_loss: 0.8819 - val_mean_absolute_error: 0.7601 - val_root_mean_squared_error: 0.9391
# Epoch 7/20
# 7/7 [==============================] - 1s 112ms/step - loss: 1.0247 - mean_absolute_error: 0.7990 - root_mean_squared_error: 1.0123 - val_loss: 0.8867 - val_mean_absolute_error: 0.7632 - val_root_mean_squared_error: 0.9416
# Epoch 8/20
# 7/7 [==============================] - 1s 106ms/step - loss: 0.9933 - mean_absolute_error: 0.7984 - root_mean_squared_error: 0.9966 - val_loss: 0.8885 - val_mean_absolute_error: 0.7651 - val_root_mean_squared_error: 0.9426
# Epoch 9/20
# 7/7 [==============================] - 1s 104ms/step - loss: 0.9453 - mean_absolute_error: 0.7845 - root_mean_squared_error: 0.9723 - val_loss: 0.8883 - val_mean_absolute_error: 0.7711 - val_root_mean_squared_error: 0.9425
# Epoch 10/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.9926 - mean_absolute_error: 0.8081 - root_mean_squared_error: 0.9963 - val_loss: 0.8995 - val_mean_absolute_error: 0.7502 - val_root_mean_squared_error: 0.9484
# Epoch 11/20
# 7/7 [==============================] - 1s 104ms/step - loss: 0.9555 - mean_absolute_error: 0.7749 - root_mean_squared_error: 0.9775 - val_loss: 0.8773 - val_mean_absolute_error: 0.7562 - val_root_mean_squared_error: 0.9367
# Epoch 12/20
# 7/7 [==============================] - 1s 106ms/step - loss: 0.9646 - mean_absolute_error: 0.7900 - root_mean_squared_error: 0.9821 - val_loss: 0.8815 - val_mean_absolute_error: 0.7693 - val_root_mean_squared_error: 0.9389
# Epoch 13/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9783 - mean_absolute_error: 0.7983 - root_mean_squared_error: 0.9891 - val_loss: 0.9122 - val_mean_absolute_error: 0.7585 - val_root_mean_squared_error: 0.9551
# Epoch 14/20
# 7/7 [==============================] - 1s 104ms/step - loss: 0.9606 - mean_absolute_error: 0.7816 - root_mean_squared_error: 0.9801 - val_loss: 0.8897 - val_mean_absolute_error: 0.7744 - val_root_mean_squared_error: 0.9433
# Epoch 15/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.9393 - mean_absolute_error: 0.7780 - root_mean_squared_error: 0.9692 - val_loss: 0.8967 - val_mean_absolute_error: 0.7812 - val_root_mean_squared_error: 0.9469
# Epoch 16/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.9661 - mean_absolute_error: 0.7722 - root_mean_squared_error: 0.9829 - val_loss: 0.9149 - val_mean_absolute_error: 0.7758 - val_root_mean_squared_error: 0.9565
# Epoch 17/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9151 - mean_absolute_error: 0.7608 - root_mean_squared_error: 0.9566 - val_loss: 0.9074 - val_mean_absolute_error: 0.7781 - val_root_mean_squared_error: 0.9526
# Epoch 18/20
# 7/7 [==============================] - 1s 106ms/step - loss: 0.9149 - mean_absolute_error: 0.7580 - root_mean_squared_error: 0.9565 - val_loss: 0.9282 - val_mean_absolute_error: 0.7746 - val_root_mean_squared_error: 0.9634
# Epoch 19/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9284 - mean_absolute_error: 0.7699 - root_mean_squared_error: 0.9635 - val_loss: 0.9136 - val_mean_absolute_error: 0.7789 - val_root_mean_squared_error: 0.9558
# Epoch 20/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9332 - mean_absolute_error: 0.7772 - root_mean_squared_error: 0.9660 - val_loss: 0.9790 - val_mean_absolute_error: 0.7771 - val_root_mean_squared_error: 0.9895
# 2/2 [==============================] - 2s 131ms/step
# 7/7 [==============================] - 1s 81ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 3------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 8s 430ms/step - loss: 23.1792 - mean_absolute_error: 3.9786 - root_mean_squared_error: 4.8145 - val_loss: 4.9019 - val_mean_absolute_error: 2.0198 - val_root_mean_squared_error: 2.2140
# Epoch 2/20
# 7/7 [==============================] - 1s 115ms/step - loss: 2.1867 - mean_absolute_error: 1.1969 - root_mean_squared_error: 1.4788 - val_loss: 1.9285 - val_mean_absolute_error: 1.0126 - val_root_mean_squared_error: 1.3887
# Epoch 3/20
# 7/7 [==============================] - 1s 114ms/step - loss: 1.6496 - mean_absolute_error: 1.0554 - root_mean_squared_error: 1.2844 - val_loss: 1.5216 - val_mean_absolute_error: 1.1088 - val_root_mean_squared_error: 1.2335
# Epoch 4/20
# 7/7 [==============================] - 1s 108ms/step - loss: 1.1280 - mean_absolute_error: 0.8442 - root_mean_squared_error: 1.0621 - val_loss: 1.0155 - val_mean_absolute_error: 0.8360 - val_root_mean_squared_error: 1.0077
# Epoch 5/20
# 7/7 [==============================] - 1s 105ms/step - loss: 1.0820 - mean_absolute_error: 0.8295 - root_mean_squared_error: 1.0402 - val_loss: 1.0327 - val_mean_absolute_error: 0.7924 - val_root_mean_squared_error: 1.0162
# Epoch 6/20
# 7/7 [==============================] - 1s 107ms/step - loss: 1.0042 - mean_absolute_error: 0.8154 - root_mean_squared_error: 1.0021 - val_loss: 1.0247 - val_mean_absolute_error: 0.8412 - val_root_mean_squared_error: 1.0123
# Epoch 7/20
# 7/7 [==============================] - 1s 105ms/step - loss: 1.0015 - mean_absolute_error: 0.7878 - root_mean_squared_error: 1.0007 - val_loss: 1.0239 - val_mean_absolute_error: 0.8400 - val_root_mean_squared_error: 1.0119
# Epoch 8/20
# 7/7 [==============================] - 1s 106ms/step - loss: 0.9557 - mean_absolute_error: 0.7819 - root_mean_squared_error: 0.9776 - val_loss: 1.0090 - val_mean_absolute_error: 0.8195 - val_root_mean_squared_error: 1.0045
# Epoch 9/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.9592 - mean_absolute_error: 0.7768 - root_mean_squared_error: 0.9794 - val_loss: 1.0063 - val_mean_absolute_error: 0.8103 - val_root_mean_squared_error: 1.0032
# Epoch 10/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.9479 - mean_absolute_error: 0.7692 - root_mean_squared_error: 0.9736 - val_loss: 1.0088 - val_mean_absolute_error: 0.8172 - val_root_mean_squared_error: 1.0044
# Epoch 11/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.9500 - mean_absolute_error: 0.7831 - root_mean_squared_error: 0.9747 - val_loss: 1.0093 - val_mean_absolute_error: 0.8290 - val_root_mean_squared_error: 1.0046
# Epoch 12/20
# 7/7 [==============================] - 1s 109ms/step - loss: 0.9213 - mean_absolute_error: 0.7533 - root_mean_squared_error: 0.9598 - val_loss: 1.0036 - val_mean_absolute_error: 0.8088 - val_root_mean_squared_error: 1.0018
# Epoch 13/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.9689 - mean_absolute_error: 0.7867 - root_mean_squared_error: 0.9843 - val_loss: 1.0112 - val_mean_absolute_error: 0.8064 - val_root_mean_squared_error: 1.0056
# Epoch 14/20
# 7/7 [==============================] - 1s 105ms/step - loss: 0.8992 - mean_absolute_error: 0.7561 - root_mean_squared_error: 0.9483 - val_loss: 1.0162 - val_mean_absolute_error: 0.8061 - val_root_mean_squared_error: 1.0081
# Epoch 15/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.8889 - mean_absolute_error: 0.7566 - root_mean_squared_error: 0.9428 - val_loss: 1.0080 - val_mean_absolute_error: 0.8158 - val_root_mean_squared_error: 1.0040
# Epoch 16/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.9240 - mean_absolute_error: 0.7697 - root_mean_squared_error: 0.9613 - val_loss: 1.0038 - val_mean_absolute_error: 0.8341 - val_root_mean_squared_error: 1.0019
# Epoch 17/20
# 7/7 [==============================] - 1s 113ms/step - loss: 0.9261 - mean_absolute_error: 0.7673 - root_mean_squared_error: 0.9623 - val_loss: 0.9956 - val_mean_absolute_error: 0.8080 - val_root_mean_squared_error: 0.9978
# Epoch 18/20
# 7/7 [==============================] - 1s 113ms/step - loss: 0.9660 - mean_absolute_error: 0.7944 - root_mean_squared_error: 0.9828 - val_loss: 1.0248 - val_mean_absolute_error: 0.7796 - val_root_mean_squared_error: 1.0123
# Epoch 19/20
# 7/7 [==============================] - 1s 112ms/step - loss: 0.9212 - mean_absolute_error: 0.7643 - root_mean_squared_error: 0.9598 - val_loss: 1.0047 - val_mean_absolute_error: 0.8262 - val_root_mean_squared_error: 1.0023
# Epoch 20/20
# 7/7 [==============================] - 1s 112ms/step - loss: 0.9423 - mean_absolute_error: 0.7740 - root_mean_squared_error: 0.9707 - val_loss: 1.0038 - val_mean_absolute_error: 0.8147 - val_root_mean_squared_error: 1.0019
# 2/2 [==============================] - 1s 123ms/step
# 7/7 [==============================] - 1s 90ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 4------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 9s 331ms/step - loss: 14.3994 - mean_absolute_error: 3.0654 - root_mean_squared_error: 3.7947 - val_loss: 0.8522 - val_mean_absolute_error: 0.7196 - val_root_mean_squared_error: 0.9232
# Epoch 2/20
# 7/7 [==============================] - 1s 109ms/step - loss: 1.7745 - mean_absolute_error: 1.1035 - root_mean_squared_error: 1.3321 - val_loss: 0.8445 - val_mean_absolute_error: 0.7155 - val_root_mean_squared_error: 0.9190
# Epoch 3/20
# 7/7 [==============================] - 1s 108ms/step - loss: 1.3443 - mean_absolute_error: 0.9072 - root_mean_squared_error: 1.1594 - val_loss: 0.8376 - val_mean_absolute_error: 0.7276 - val_root_mean_squared_error: 0.9152
# Epoch 4/20
# 7/7 [==============================] - 1s 106ms/step - loss: 1.3195 - mean_absolute_error: 0.9502 - root_mean_squared_error: 1.1487 - val_loss: 0.8907 - val_mean_absolute_error: 0.7310 - val_root_mean_squared_error: 0.9438
# Epoch 5/20
# 7/7 [==============================] - 1s 106ms/step - loss: 1.1508 - mean_absolute_error: 0.8589 - root_mean_squared_error: 1.0728 - val_loss: 1.0494 - val_mean_absolute_error: 0.8265 - val_root_mean_squared_error: 1.0244
# Epoch 6/20
# 7/7 [==============================] - 1s 109ms/step - loss: 1.0726 - mean_absolute_error: 0.8249 - root_mean_squared_error: 1.0357 - val_loss: 0.8681 - val_mean_absolute_error: 0.7404 - val_root_mean_squared_error: 0.9317
# Epoch 7/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9953 - mean_absolute_error: 0.8014 - root_mean_squared_error: 0.9977 - val_loss: 0.8904 - val_mean_absolute_error: 0.7559 - val_root_mean_squared_error: 0.9436
# Epoch 8/20
# 7/7 [==============================] - 1s 106ms/step - loss: 0.9146 - mean_absolute_error: 0.7729 - root_mean_squared_error: 0.9564 - val_loss: 0.8664 - val_mean_absolute_error: 0.7341 - val_root_mean_squared_error: 0.9308
# Epoch 9/20
# 7/7 [==============================] - 1s 107ms/step - loss: 0.9267 - mean_absolute_error: 0.7671 - root_mean_squared_error: 0.9626 - val_loss: 0.9031 - val_mean_absolute_error: 0.7654 - val_root_mean_squared_error: 0.9503
# Epoch 10/20
# 7/7 [==============================] - 1s 106ms/step - loss: 0.9302 - mean_absolute_error: 0.7757 - root_mean_squared_error: 0.9645 - val_loss: 0.9109 - val_mean_absolute_error: 0.7690 - val_root_mean_squared_error: 0.9544
# Epoch 11/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.8997 - mean_absolute_error: 0.7548 - root_mean_squared_error: 0.9485 - val_loss: 0.8772 - val_mean_absolute_error: 0.7440 - val_root_mean_squared_error: 0.9366
# Epoch 12/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.9242 - mean_absolute_error: 0.7660 - root_mean_squared_error: 0.9613 - val_loss: 0.9053 - val_mean_absolute_error: 0.7650 - val_root_mean_squared_error: 0.9514
# Epoch 13/20
# 7/7 [==============================] - 1s 115ms/step - loss: 0.9469 - mean_absolute_error: 0.7746 - root_mean_squared_error: 0.9731 - val_loss: 0.8628 - val_mean_absolute_error: 0.7365 - val_root_mean_squared_error: 0.9289
# Epoch 14/20
# 7/7 [==============================] - 1s 120ms/step - loss: 0.8934 - mean_absolute_error: 0.7647 - root_mean_squared_error: 0.9452 - val_loss: 0.8462 - val_mean_absolute_error: 0.7267 - val_root_mean_squared_error: 0.9199
# Epoch 15/20
# 7/7 [==============================] - 1s 118ms/step - loss: 0.8726 - mean_absolute_error: 0.7526 - root_mean_squared_error: 0.9341 - val_loss: 0.8628 - val_mean_absolute_error: 0.7494 - val_root_mean_squared_error: 0.9289
# Epoch 16/20
# 7/7 [==============================] - 1s 112ms/step - loss: 0.8845 - mean_absolute_error: 0.7531 - root_mean_squared_error: 0.9405 - val_loss: 0.8394 - val_mean_absolute_error: 0.7273 - val_root_mean_squared_error: 0.9162
# Epoch 17/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.8766 - mean_absolute_error: 0.7518 - root_mean_squared_error: 0.9363 - val_loss: 0.8434 - val_mean_absolute_error: 0.7302 - val_root_mean_squared_error: 0.9184
# Epoch 18/20
# 7/7 [==============================] - 1s 109ms/step - loss: 0.8828 - mean_absolute_error: 0.7651 - root_mean_squared_error: 0.9396 - val_loss: 0.8463 - val_mean_absolute_error: 0.7284 - val_root_mean_squared_error: 0.9199
# Epoch 19/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.9232 - mean_absolute_error: 0.7751 - root_mean_squared_error: 0.9608 - val_loss: 0.8483 - val_mean_absolute_error: 0.7309 - val_root_mean_squared_error: 0.9211
# Epoch 20/20
# 7/7 [==============================] - 1s 108ms/step - loss: 0.8627 - mean_absolute_error: 0.7505 - root_mean_squared_error: 0.9288 - val_loss: 0.8769 - val_mean_absolute_error: 0.7544 - val_root_mean_squared_error: 0.9364
# 2/2 [==============================] - 1s 75ms/step
# 7/7 [==============================] - 1s 80ms/step

# %%
print('Total validation RMSE:', mean_squared_error(np.concatenate(all_val_true).ravel(),np.concatenate(all_val_preds).ravel(),squared=False))
# Out:
# Total validation RMSE: 0.9950804156850587

# %%
print('Total validation MAE:', mean_absolute_error(np.concatenate(all_val_true).ravel(),np.concatenate(all_val_preds).ravel()))
# Out:
# Total validation MAE: 0.7966715192573912

# %% [markdown]
# #DenseNet

# %%
all_val_preds = []
all_val_true = []

for i,(train_idx,test_idx) in enumerate(kf.split(X_col)):
  print('-'*66)
  print('-'*30+f'Fold {i}'+'-'*30)
  print('-'*66)

  X_train = np.take(X_col, train_idx, axis=0)
  y_train = np.take(y, train_idx, axis=0)

  X_val = np.take(X_col, test_idx, axis=0)
  y_val = np.take(y, test_idx, axis=0)
  y_train,y_val = scale_fit_transform(y_train,y_val)

  model = build_densenet((256,256,3),512,0,0.01)
  h = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val,y_val))
  plot_metrics(h,['loss','root_mean_squared_error','mean_absolute_error'],f'D1 WSA: DenseNet169 split{i}')


  y_val_pred = model.predict(X_val)
  y_train_pred = model.predict(X_train)
  all_val_preds.append(y_val_pred)
  all_val_true.append(y_val)


  plot_predictions(y_val.reshape(-1, 1),y_val_pred,y_train.reshape(-1, 1),y_train_pred,f'D1 WSA: DenseNet split {i}')

plot_all_validation(all_val_true,all_val_preds,'D1 WSA: DenseNet169 total validation')
# Out:
# ------------------------------------------------------------------
# ------------------------------Fold 0------------------------------
# ------------------------------------------------------------------
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 0s 0us/step
# Epoch 1/20
# 7/7 [==============================] - 30s 2s/step - loss: 635.9623 - mean_absolute_error: 21.1233 - root_mean_squared_error: 25.2183 - val_loss: 0.7091 - val_mean_absolute_error: 0.6637 - val_root_mean_squared_error: 0.8421
# Epoch 2/20
# 7/7 [==============================] - 1s 161ms/step - loss: 69.3303 - mean_absolute_error: 7.4337 - root_mean_squared_error: 8.3265 - val_loss: 5.3058 - val_mean_absolute_error: 2.1496 - val_root_mean_squared_error: 2.3034
# Epoch 3/20
# 7/7 [==============================] - 1s 160ms/step - loss: 23.9745 - mean_absolute_error: 4.5077 - root_mean_squared_error: 4.8964 - val_loss: 1.0325 - val_mean_absolute_error: 0.8021 - val_root_mean_squared_error: 1.0161
# Epoch 4/20
# 7/7 [==============================] - 1s 178ms/step - loss: 8.2349 - mean_absolute_error: 2.5722 - root_mean_squared_error: 2.8696 - val_loss: 3.5634 - val_mean_absolute_error: 1.6994 - val_root_mean_squared_error: 1.8877
# Epoch 5/20
# 7/7 [==============================] - 1s 160ms/step - loss: 2.5311 - mean_absolute_error: 1.3288 - root_mean_squared_error: 1.5910 - val_loss: 0.8230 - val_mean_absolute_error: 0.7255 - val_root_mean_squared_error: 0.9072
# Epoch 6/20
# 7/7 [==============================] - 1s 176ms/step - loss: 1.2348 - mean_absolute_error: 0.8967 - root_mean_squared_error: 1.1112 - val_loss: 0.9157 - val_mean_absolute_error: 0.7823 - val_root_mean_squared_error: 0.9569
# Epoch 7/20
# 7/7 [==============================] - 1s 183ms/step - loss: 1.0418 - mean_absolute_error: 0.8154 - root_mean_squared_error: 1.0207 - val_loss: 1.1738 - val_mean_absolute_error: 0.8965 - val_root_mean_squared_error: 1.0834
# Epoch 8/20
# 7/7 [==============================] - 1s 173ms/step - loss: 1.3587 - mean_absolute_error: 0.9477 - root_mean_squared_error: 1.1656 - val_loss: 0.7080 - val_mean_absolute_error: 0.6707 - val_root_mean_squared_error: 0.8414
# Epoch 9/20
# 7/7 [==============================] - 1s 173ms/step - loss: 1.0772 - mean_absolute_error: 0.8522 - root_mean_squared_error: 1.0379 - val_loss: 0.8751 - val_mean_absolute_error: 0.7560 - val_root_mean_squared_error: 0.9355
# Epoch 10/20
# 7/7 [==============================] - 1s 178ms/step - loss: 1.1113 - mean_absolute_error: 0.8410 - root_mean_squared_error: 1.0542 - val_loss: 0.8284 - val_mean_absolute_error: 0.7226 - val_root_mean_squared_error: 0.9102
# Epoch 11/20
# 7/7 [==============================] - 1s 160ms/step - loss: 0.9808 - mean_absolute_error: 0.8083 - root_mean_squared_error: 0.9903 - val_loss: 1.9515 - val_mean_absolute_error: 1.1588 - val_root_mean_squared_error: 1.3970
# Epoch 12/20
# 7/7 [==============================] - 1s 162ms/step - loss: 1.2310 - mean_absolute_error: 0.8913 - root_mean_squared_error: 1.1095 - val_loss: 0.6773 - val_mean_absolute_error: 0.6555 - val_root_mean_squared_error: 0.8230
# Epoch 13/20
# 7/7 [==============================] - 1s 162ms/step - loss: 1.0778 - mean_absolute_error: 0.8109 - root_mean_squared_error: 1.0382 - val_loss: 0.6677 - val_mean_absolute_error: 0.6513 - val_root_mean_squared_error: 0.8171
# Epoch 14/20
# 7/7 [==============================] - 1s 162ms/step - loss: 0.9391 - mean_absolute_error: 0.7904 - root_mean_squared_error: 0.9691 - val_loss: 0.6736 - val_mean_absolute_error: 0.6513 - val_root_mean_squared_error: 0.8207
# Epoch 15/20
# 7/7 [==============================] - 1s 164ms/step - loss: 1.0092 - mean_absolute_error: 0.7918 - root_mean_squared_error: 1.0046 - val_loss: 0.6668 - val_mean_absolute_error: 0.6467 - val_root_mean_squared_error: 0.8166
# Epoch 16/20
# 7/7 [==============================] - 1s 161ms/step - loss: 1.0173 - mean_absolute_error: 0.8139 - root_mean_squared_error: 1.0086 - val_loss: 0.6697 - val_mean_absolute_error: 0.6455 - val_root_mean_squared_error: 0.8184
# Epoch 17/20
# 7/7 [==============================] - 1s 177ms/step - loss: 0.9359 - mean_absolute_error: 0.7743 - root_mean_squared_error: 0.9674 - val_loss: 0.6743 - val_mean_absolute_error: 0.6478 - val_root_mean_squared_error: 0.8211
# Epoch 18/20
# 7/7 [==============================] - 1s 185ms/step - loss: 1.0014 - mean_absolute_error: 0.8137 - root_mean_squared_error: 1.0007 - val_loss: 0.6618 - val_mean_absolute_error: 0.6423 - val_root_mean_squared_error: 0.8135
# Epoch 19/20
# 7/7 [==============================] - 1s 175ms/step - loss: 0.9335 - mean_absolute_error: 0.7826 - root_mean_squared_error: 0.9662 - val_loss: 0.6607 - val_mean_absolute_error: 0.6427 - val_root_mean_squared_error: 0.8129
# Epoch 20/20
# 7/7 [==============================] - 1s 190ms/step - loss: 0.9279 - mean_absolute_error: 0.7793 - root_mean_squared_error: 0.9633 - val_loss: 0.6507 - val_mean_absolute_error: 0.6348 - val_root_mean_squared_error: 0.8067
# 2/2 [==============================] - 4s 180ms/step
# 7/7 [==============================] - 1s 125ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 1------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 16s 715ms/step - loss: 817.1640 - mean_absolute_error: 20.0320 - root_mean_squared_error: 28.5861 - val_loss: 25.5056 - val_mean_absolute_error: 4.8994 - val_root_mean_squared_error: 5.0503
# Epoch 2/20
# 7/7 [==============================] - 1s 159ms/step - loss: 13.4975 - mean_absolute_error: 3.3074 - root_mean_squared_error: 3.6739 - val_loss: 1.6070 - val_mean_absolute_error: 1.0118 - val_root_mean_squared_error: 1.2677
# Epoch 3/20
# 7/7 [==============================] - 1s 177ms/step - loss: 4.5184 - mean_absolute_error: 1.7570 - root_mean_squared_error: 2.1257 - val_loss: 2.2303 - val_mean_absolute_error: 1.2318 - val_root_mean_squared_error: 1.4934
# Epoch 4/20
# 7/7 [==============================] - 1s 174ms/step - loss: 2.7132 - mean_absolute_error: 1.3480 - root_mean_squared_error: 1.6472 - val_loss: 2.1750 - val_mean_absolute_error: 1.1947 - val_root_mean_squared_error: 1.4748
# Epoch 5/20
# 7/7 [==============================] - 1s 159ms/step - loss: 1.0526 - mean_absolute_error: 0.8108 - root_mean_squared_error: 1.0260 - val_loss: 1.6334 - val_mean_absolute_error: 1.0634 - val_root_mean_squared_error: 1.2780
# Epoch 6/20
# 7/7 [==============================] - 1s 159ms/step - loss: 0.9901 - mean_absolute_error: 0.7986 - root_mean_squared_error: 0.9951 - val_loss: 1.5829 - val_mean_absolute_error: 1.0281 - val_root_mean_squared_error: 1.2581
# Epoch 7/20
# 7/7 [==============================] - 1s 176ms/step - loss: 1.0410 - mean_absolute_error: 0.8255 - root_mean_squared_error: 1.0203 - val_loss: 1.5905 - val_mean_absolute_error: 1.0271 - val_root_mean_squared_error: 1.2611
# Epoch 8/20
# 7/7 [==============================] - 1s 176ms/step - loss: 0.9369 - mean_absolute_error: 0.7718 - root_mean_squared_error: 0.9679 - val_loss: 1.4464 - val_mean_absolute_error: 0.9748 - val_root_mean_squared_error: 1.2027
# Epoch 9/20
# 7/7 [==============================] - 1s 181ms/step - loss: 0.8962 - mean_absolute_error: 0.7528 - root_mean_squared_error: 0.9467 - val_loss: 2.1580 - val_mean_absolute_error: 1.1603 - val_root_mean_squared_error: 1.4690
# Epoch 10/20
# 7/7 [==============================] - 1s 173ms/step - loss: 1.0554 - mean_absolute_error: 0.8406 - root_mean_squared_error: 1.0273 - val_loss: 1.7517 - val_mean_absolute_error: 1.0564 - val_root_mean_squared_error: 1.3235
# Epoch 11/20
# 7/7 [==============================] - 1s 169ms/step - loss: 1.0214 - mean_absolute_error: 0.8167 - root_mean_squared_error: 1.0107 - val_loss: 1.7297 - val_mean_absolute_error: 1.0397 - val_root_mean_squared_error: 1.3152
# Epoch 12/20
# 7/7 [==============================] - 1s 176ms/step - loss: 1.0069 - mean_absolute_error: 0.7999 - root_mean_squared_error: 1.0035 - val_loss: 1.3991 - val_mean_absolute_error: 0.9489 - val_root_mean_squared_error: 1.1828
# Epoch 13/20
# 7/7 [==============================] - 1s 160ms/step - loss: 1.0791 - mean_absolute_error: 0.8294 - root_mean_squared_error: 1.0388 - val_loss: 1.4112 - val_mean_absolute_error: 0.9639 - val_root_mean_squared_error: 1.1879
# Epoch 14/20
# 7/7 [==============================] - 1s 176ms/step - loss: 0.8448 - mean_absolute_error: 0.7454 - root_mean_squared_error: 0.9191 - val_loss: 1.3864 - val_mean_absolute_error: 0.9469 - val_root_mean_squared_error: 1.1775
# Epoch 15/20
# 7/7 [==============================] - 1s 159ms/step - loss: 1.2734 - mean_absolute_error: 0.8919 - root_mean_squared_error: 1.1285 - val_loss: 1.5726 - val_mean_absolute_error: 1.0151 - val_root_mean_squared_error: 1.2541
# Epoch 16/20
# 7/7 [==============================] - 1s 158ms/step - loss: 1.3720 - mean_absolute_error: 0.9552 - root_mean_squared_error: 1.1713 - val_loss: 1.3217 - val_mean_absolute_error: 0.9373 - val_root_mean_squared_error: 1.1497
# Epoch 17/20
# 7/7 [==============================] - 1s 160ms/step - loss: 0.8950 - mean_absolute_error: 0.7588 - root_mean_squared_error: 0.9461 - val_loss: 1.3224 - val_mean_absolute_error: 0.9237 - val_root_mean_squared_error: 1.1499
# Epoch 18/20
# 7/7 [==============================] - 1s 162ms/step - loss: 1.0148 - mean_absolute_error: 0.8017 - root_mean_squared_error: 1.0074 - val_loss: 1.3442 - val_mean_absolute_error: 0.9429 - val_root_mean_squared_error: 1.1594
# Epoch 19/20
# 7/7 [==============================] - 1s 161ms/step - loss: 1.1411 - mean_absolute_error: 0.8656 - root_mean_squared_error: 1.0682 - val_loss: 2.2416 - val_mean_absolute_error: 1.1770 - val_root_mean_squared_error: 1.4972
# Epoch 20/20
# 7/7 [==============================] - 1s 167ms/step - loss: 1.0836 - mean_absolute_error: 0.8288 - root_mean_squared_error: 1.0409 - val_loss: 1.6664 - val_mean_absolute_error: 1.0263 - val_root_mean_squared_error: 1.2909
# 2/2 [==============================] - 3s 166ms/step
# 7/7 [==============================] - 1s 125ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 2------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 24s 2s/step - loss: 857.3618 - mean_absolute_error: 21.2432 - root_mean_squared_error: 29.2807 - val_loss: 50.6851 - val_mean_absolute_error: 7.0451 - val_root_mean_squared_error: 7.1193
# Epoch 2/20
# 7/7 [==============================] - 1s 181ms/step - loss: 36.5785 - mean_absolute_error: 5.5111 - root_mean_squared_error: 6.0480 - val_loss: 17.9660 - val_mean_absolute_error: 4.1184 - val_root_mean_squared_error: 4.2386
# Epoch 3/20
# 7/7 [==============================] - 1s 174ms/step - loss: 12.0085 - mean_absolute_error: 3.0748 - root_mean_squared_error: 3.4653 - val_loss: 2.8237 - val_mean_absolute_error: 1.4547 - val_root_mean_squared_error: 1.6804
# Epoch 4/20
# 7/7 [==============================] - 1s 174ms/step - loss: 3.1956 - mean_absolute_error: 1.4620 - root_mean_squared_error: 1.7876 - val_loss: 3.7927 - val_mean_absolute_error: 1.7276 - val_root_mean_squared_error: 1.9475
# Epoch 5/20
# 7/7 [==============================] - 1s 180ms/step - loss: 2.2346 - mean_absolute_error: 1.2222 - root_mean_squared_error: 1.4949 - val_loss: 2.1022 - val_mean_absolute_error: 1.1886 - val_root_mean_squared_error: 1.4499
# Epoch 6/20
# 7/7 [==============================] - 1s 178ms/step - loss: 1.7496 - mean_absolute_error: 1.0436 - root_mean_squared_error: 1.3227 - val_loss: 1.9359 - val_mean_absolute_error: 1.1908 - val_root_mean_squared_error: 1.3914
# Epoch 7/20
# 7/7 [==============================] - 1s 161ms/step - loss: 1.2343 - mean_absolute_error: 0.8923 - root_mean_squared_error: 1.1110 - val_loss: 1.1805 - val_mean_absolute_error: 0.8713 - val_root_mean_squared_error: 1.0865
# Epoch 8/20
# 7/7 [==============================] - 1s 180ms/step - loss: 1.1852 - mean_absolute_error: 0.8646 - root_mean_squared_error: 1.0887 - val_loss: 0.9472 - val_mean_absolute_error: 0.7960 - val_root_mean_squared_error: 0.9732
# Epoch 9/20
# 7/7 [==============================] - 1s 162ms/step - loss: 0.9952 - mean_absolute_error: 0.8198 - root_mean_squared_error: 0.9976 - val_loss: 0.8391 - val_mean_absolute_error: 0.7475 - val_root_mean_squared_error: 0.9161
# Epoch 10/20
# 7/7 [==============================] - 1s 179ms/step - loss: 1.1459 - mean_absolute_error: 0.8616 - root_mean_squared_error: 1.0705 - val_loss: 0.9567 - val_mean_absolute_error: 0.8081 - val_root_mean_squared_error: 0.9781
# Epoch 11/20
# 7/7 [==============================] - 1s 180ms/step - loss: 1.3475 - mean_absolute_error: 0.9570 - root_mean_squared_error: 1.1608 - val_loss: 1.2143 - val_mean_absolute_error: 0.8774 - val_root_mean_squared_error: 1.1020
# Epoch 12/20
# 7/7 [==============================] - 1s 163ms/step - loss: 1.1361 - mean_absolute_error: 0.8630 - root_mean_squared_error: 1.0659 - val_loss: 1.0567 - val_mean_absolute_error: 0.8499 - val_root_mean_squared_error: 1.0280
# Epoch 13/20
# 7/7 [==============================] - 1s 169ms/step - loss: 1.0279 - mean_absolute_error: 0.7955 - root_mean_squared_error: 1.0139 - val_loss: 0.9612 - val_mean_absolute_error: 0.7835 - val_root_mean_squared_error: 0.9804
# Epoch 14/20
# 7/7 [==============================] - 1s 174ms/step - loss: 1.0340 - mean_absolute_error: 0.8132 - root_mean_squared_error: 1.0169 - val_loss: 0.8540 - val_mean_absolute_error: 0.7331 - val_root_mean_squared_error: 0.9241
# Epoch 15/20
# 7/7 [==============================] - 1s 194ms/step - loss: 0.9841 - mean_absolute_error: 0.7932 - root_mean_squared_error: 0.9920 - val_loss: 0.9912 - val_mean_absolute_error: 0.8261 - val_root_mean_squared_error: 0.9956
# Epoch 16/20
# 7/7 [==============================] - 1s 179ms/step - loss: 1.0506 - mean_absolute_error: 0.8226 - root_mean_squared_error: 1.0250 - val_loss: 0.8861 - val_mean_absolute_error: 0.7464 - val_root_mean_squared_error: 0.9413
# Epoch 17/20
# 7/7 [==============================] - 1s 162ms/step - loss: 0.9968 - mean_absolute_error: 0.7995 - root_mean_squared_error: 0.9984 - val_loss: 0.8134 - val_mean_absolute_error: 0.7436 - val_root_mean_squared_error: 0.9019
# Epoch 18/20
# 7/7 [==============================] - 1s 179ms/step - loss: 0.9101 - mean_absolute_error: 0.7683 - root_mean_squared_error: 0.9540 - val_loss: 0.8407 - val_mean_absolute_error: 0.7342 - val_root_mean_squared_error: 0.9169
# Epoch 19/20
# 7/7 [==============================] - 1s 180ms/step - loss: 0.9649 - mean_absolute_error: 0.7932 - root_mean_squared_error: 0.9823 - val_loss: 0.8078 - val_mean_absolute_error: 0.7375 - val_root_mean_squared_error: 0.8988
# Epoch 20/20
# 7/7 [==============================] - 1s 179ms/step - loss: 0.9027 - mean_absolute_error: 0.7603 - root_mean_squared_error: 0.9501 - val_loss: 0.8933 - val_mean_absolute_error: 0.7500 - val_root_mean_squared_error: 0.9452
# 2/2 [==============================] - 3s 171ms/step
# 7/7 [==============================] - 1s 124ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 3------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 17s 768ms/step - loss: 1136.8966 - mean_absolute_error: 19.5193 - root_mean_squared_error: 33.7179 - val_loss: 10.7507 - val_mean_absolute_error: 3.1092 - val_root_mean_squared_error: 3.2788
# Epoch 2/20
# 7/7 [==============================] - 1s 160ms/step - loss: 6.5060 - mean_absolute_error: 2.1929 - root_mean_squared_error: 2.5507 - val_loss: 3.7884 - val_mean_absolute_error: 1.6505 - val_root_mean_squared_error: 1.9464
# Epoch 3/20
# 7/7 [==============================] - 1s 159ms/step - loss: 1.9730 - mean_absolute_error: 1.1535 - root_mean_squared_error: 1.4047 - val_loss: 1.1638 - val_mean_absolute_error: 0.7812 - val_root_mean_squared_error: 1.0788
# Epoch 4/20
# 7/7 [==============================] - 1s 159ms/step - loss: 1.1750 - mean_absolute_error: 0.8696 - root_mean_squared_error: 1.0840 - val_loss: 1.1069 - val_mean_absolute_error: 0.9049 - val_root_mean_squared_error: 1.0521
# Epoch 5/20
# 7/7 [==============================] - 1s 159ms/step - loss: 1.1149 - mean_absolute_error: 0.8329 - root_mean_squared_error: 1.0559 - val_loss: 1.1153 - val_mean_absolute_error: 0.9062 - val_root_mean_squared_error: 1.0561
# Epoch 6/20
# 7/7 [==============================] - 1s 177ms/step - loss: 1.0435 - mean_absolute_error: 0.8160 - root_mean_squared_error: 1.0215 - val_loss: 1.1839 - val_mean_absolute_error: 0.7859 - val_root_mean_squared_error: 1.0881
# Epoch 7/20
# 7/7 [==============================] - 1s 161ms/step - loss: 1.0076 - mean_absolute_error: 0.8035 - root_mean_squared_error: 1.0038 - val_loss: 1.3368 - val_mean_absolute_error: 1.0197 - val_root_mean_squared_error: 1.1562
# Epoch 8/20
# 7/7 [==============================] - 1s 161ms/step - loss: 1.1156 - mean_absolute_error: 0.8640 - root_mean_squared_error: 1.0562 - val_loss: 1.2414 - val_mean_absolute_error: 0.8110 - val_root_mean_squared_error: 1.1142
# Epoch 9/20
# 7/7 [==============================] - 1s 178ms/step - loss: 1.1673 - mean_absolute_error: 0.8729 - root_mean_squared_error: 1.0804 - val_loss: 1.3082 - val_mean_absolute_error: 0.9719 - val_root_mean_squared_error: 1.1437
# Epoch 10/20
# 7/7 [==============================] - 1s 179ms/step - loss: 1.0486 - mean_absolute_error: 0.8023 - root_mean_squared_error: 1.0240 - val_loss: 2.0829 - val_mean_absolute_error: 1.2901 - val_root_mean_squared_error: 1.4432
# Epoch 11/20
# 7/7 [==============================] - 1s 190ms/step - loss: 1.4827 - mean_absolute_error: 0.9803 - root_mean_squared_error: 1.2177 - val_loss: 1.2637 - val_mean_absolute_error: 0.9531 - val_root_mean_squared_error: 1.1242
# Epoch 12/20
# 7/7 [==============================] - 1s 171ms/step - loss: 0.9914 - mean_absolute_error: 0.7880 - root_mean_squared_error: 0.9957 - val_loss: 1.1211 - val_mean_absolute_error: 0.8630 - val_root_mean_squared_error: 1.0588
# Epoch 13/20
# 7/7 [==============================] - 1s 177ms/step - loss: 1.0015 - mean_absolute_error: 0.7901 - root_mean_squared_error: 1.0008 - val_loss: 1.1670 - val_mean_absolute_error: 0.8989 - val_root_mean_squared_error: 1.0803
# Epoch 14/20
# 7/7 [==============================] - 1s 161ms/step - loss: 1.2629 - mean_absolute_error: 0.8956 - root_mean_squared_error: 1.1238 - val_loss: 1.2253 - val_mean_absolute_error: 0.7977 - val_root_mean_squared_error: 1.1069
# Epoch 15/20
# 7/7 [==============================] - 1s 179ms/step - loss: 0.9857 - mean_absolute_error: 0.7953 - root_mean_squared_error: 0.9928 - val_loss: 1.2653 - val_mean_absolute_error: 0.8046 - val_root_mean_squared_error: 1.1248
# Epoch 16/20
# 7/7 [==============================] - 1s 179ms/step - loss: 0.9928 - mean_absolute_error: 0.8048 - root_mean_squared_error: 0.9964 - val_loss: 1.0831 - val_mean_absolute_error: 0.8186 - val_root_mean_squared_error: 1.0407
# Epoch 17/20
# 7/7 [==============================] - 1s 161ms/step - loss: 0.9318 - mean_absolute_error: 0.7538 - root_mean_squared_error: 0.9653 - val_loss: 1.1177 - val_mean_absolute_error: 0.8625 - val_root_mean_squared_error: 1.0572
# Epoch 18/20
# 7/7 [==============================] - 1s 181ms/step - loss: 0.9034 - mean_absolute_error: 0.7493 - root_mean_squared_error: 0.9505 - val_loss: 1.0961 - val_mean_absolute_error: 0.8469 - val_root_mean_squared_error: 1.0470
# Epoch 19/20
# 7/7 [==============================] - 1s 162ms/step - loss: 0.8714 - mean_absolute_error: 0.7504 - root_mean_squared_error: 0.9335 - val_loss: 1.2530 - val_mean_absolute_error: 0.7974 - val_root_mean_squared_error: 1.1194
# Epoch 20/20
# 7/7 [==============================] - 1s 162ms/step - loss: 0.9878 - mean_absolute_error: 0.8043 - root_mean_squared_error: 0.9939 - val_loss: 1.1026 - val_mean_absolute_error: 0.8034 - val_root_mean_squared_error: 1.0501
# 2/2 [==============================] - 3s 164ms/step
# 7/7 [==============================] - 1s 125ms/step
# ------------------------------------------------------------------
# ------------------------------Fold 4------------------------------
# ------------------------------------------------------------------
# Epoch 1/20
# 7/7 [==============================] - 17s 753ms/step - loss: 773.5618 - mean_absolute_error: 16.0979 - root_mean_squared_error: 27.8130 - val_loss: 5.0969 - val_mean_absolute_error: 2.0745 - val_root_mean_squared_error: 2.2576
# Epoch 2/20
# 7/7 [==============================] - 1s 162ms/step - loss: 4.5733 - mean_absolute_error: 1.7987 - root_mean_squared_error: 2.1385 - val_loss: 4.0345 - val_mean_absolute_error: 1.8119 - val_root_mean_squared_error: 2.0086
# Epoch 3/20
# 7/7 [==============================] - 1s 162ms/step - loss: 2.3941 - mean_absolute_error: 1.2501 - root_mean_squared_error: 1.5473 - val_loss: 1.0557 - val_mean_absolute_error: 0.8404 - val_root_mean_squared_error: 1.0275
# Epoch 4/20
# 7/7 [==============================] - 1s 162ms/step - loss: 1.1920 - mean_absolute_error: 0.9000 - root_mean_squared_error: 1.0918 - val_loss: 0.7883 - val_mean_absolute_error: 0.6706 - val_root_mean_squared_error: 0.8879
# Epoch 5/20
# 7/7 [==============================] - 1s 161ms/step - loss: 1.1665 - mean_absolute_error: 0.8702 - root_mean_squared_error: 1.0800 - val_loss: 1.0540 - val_mean_absolute_error: 0.8309 - val_root_mean_squared_error: 1.0266
# Epoch 6/20
# 7/7 [==============================] - 1s 178ms/step - loss: 1.4906 - mean_absolute_error: 0.9832 - root_mean_squared_error: 1.2209 - val_loss: 0.8967 - val_mean_absolute_error: 0.7553 - val_root_mean_squared_error: 0.9469
# Epoch 7/20
# 7/7 [==============================] - 1s 179ms/step - loss: 1.1471 - mean_absolute_error: 0.8733 - root_mean_squared_error: 1.0710 - val_loss: 1.1773 - val_mean_absolute_error: 0.8856 - val_root_mean_squared_error: 1.0850
# Epoch 8/20
# 7/7 [==============================] - 1s 162ms/step - loss: 1.3316 - mean_absolute_error: 0.8901 - root_mean_squared_error: 1.1539 - val_loss: 0.8087 - val_mean_absolute_error: 0.7034 - val_root_mean_squared_error: 0.8993
# Epoch 9/20
# 7/7 [==============================] - 1s 163ms/step - loss: 1.0154 - mean_absolute_error: 0.8220 - root_mean_squared_error: 1.0077 - val_loss: 1.7039 - val_mean_absolute_error: 1.0674 - val_root_mean_squared_error: 1.3053
# Epoch 10/20
# 7/7 [==============================] - 1s 179ms/step - loss: 1.1771 - mean_absolute_error: 0.8475 - root_mean_squared_error: 1.0849 - val_loss: 0.8482 - val_mean_absolute_error: 0.7266 - val_root_mean_squared_error: 0.9210
# Epoch 11/20
# 7/7 [==============================] - 1s 192ms/step - loss: 1.1187 - mean_absolute_error: 0.8504 - root_mean_squared_error: 1.0577 - val_loss: 0.8436 - val_mean_absolute_error: 0.7156 - val_root_mean_squared_error: 0.9185
# Epoch 12/20
# 7/7 [==============================] - 1s 193ms/step - loss: 1.0833 - mean_absolute_error: 0.8276 - root_mean_squared_error: 1.0408 - val_loss: 0.9251 - val_mean_absolute_error: 0.7640 - val_root_mean_squared_error: 0.9618
# Epoch 13/20
# 7/7 [==============================] - 1s 180ms/step - loss: 1.1868 - mean_absolute_error: 0.8919 - root_mean_squared_error: 1.0894 - val_loss: 0.8938 - val_mean_absolute_error: 0.7532 - val_root_mean_squared_error: 0.9454
# Epoch 14/20
# 7/7 [==============================] - 1s 180ms/step - loss: 1.0239 - mean_absolute_error: 0.8310 - root_mean_squared_error: 1.0119 - val_loss: 1.2592 - val_mean_absolute_error: 0.9128 - val_root_mean_squared_error: 1.1221
# Epoch 15/20
# 7/7 [==============================] - 1s 180ms/step - loss: 1.0547 - mean_absolute_error: 0.8308 - root_mean_squared_error: 1.0270 - val_loss: 0.9775 - val_mean_absolute_error: 0.7962 - val_root_mean_squared_error: 0.9887
# Epoch 16/20
# 7/7 [==============================] - 1s 181ms/step - loss: 0.9912 - mean_absolute_error: 0.7667 - root_mean_squared_error: 0.9956 - val_loss: 0.9360 - val_mean_absolute_error: 0.7761 - val_root_mean_squared_error: 0.9675
# Epoch 17/20
# 7/7 [==============================] - 1s 165ms/step - loss: 0.9316 - mean_absolute_error: 0.7631 - root_mean_squared_error: 0.9652 - val_loss: 0.8421 - val_mean_absolute_error: 0.7176 - val_root_mean_squared_error: 0.9176
# Epoch 18/20
# 7/7 [==============================] - 1s 164ms/step - loss: 0.8819 - mean_absolute_error: 0.7703 - root_mean_squared_error: 0.9391 - val_loss: 2.1837 - val_mean_absolute_error: 1.2097 - val_root_mean_squared_error: 1.4777
# Epoch 19/20
# 7/7 [==============================] - 1s 182ms/step - loss: 1.2418 - mean_absolute_error: 0.8897 - root_mean_squared_error: 1.1144 - val_loss: 1.6180 - val_mean_absolute_error: 1.0404 - val_root_mean_squared_error: 1.2720
# Epoch 20/20
# 7/7 [==============================] - 1s 163ms/step - loss: 1.0796 - mean_absolute_error: 0.8426 - root_mean_squared_error: 1.0391 - val_loss: 1.0732 - val_mean_absolute_error: 0.8428 - val_root_mean_squared_error: 1.0359
# 2/2 [==============================] - 4s 174ms/step
# 7/7 [==============================] - 1s 126ms/step

# %%
print('Total validation RMSE:', mean_squared_error(np.concatenate(all_val_true).ravel(),np.concatenate(all_val_preds).ravel(),squared=False))
# Out:
# Total validation RMSE: 1.0382271617384085

# %%
print('Total validation MAE:', mean_absolute_error(np.concatenate(all_val_true).ravel(),np.concatenate(all_val_preds).ravel()))
# Out:
# Total validation MAE: 0.8116339194551307
